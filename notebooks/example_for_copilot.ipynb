# %%
# Cell 2: small demo
import math

def example_compute(x):
    """Return sqrt(x) multiplied by a friendly message.
    Copilot can suggest improvements inline.
    """
    return math.sqrt(x) * 1.0

example_compute(16)
